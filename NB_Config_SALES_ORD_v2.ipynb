# %%
SD_TABLE_CONFIGS = {

    # ── VBAK — Sales Document Header─────────────────────────────────────────
    'VBAK': {
        'primary_keys': ['VBELN'],
        'sk_col':       'Sales_Order_SK',
        'gold_name':    'Fact_Sales_Doc_Item',
        'silver_cols':  [
            'VBELN','ERDAT','ERZET','ERNAM','AUDAT','VBTYP','AUART','AUTLF',
            'AUGRU','LIFSK','FAKSK','NETWR','WAERK','VKORG','VTWEG','SPART',
            'VKGRP','VKBUR','KNUMV','VDATU','VSBED','FKARA','BSTNK','BSARK',
            'BSTDK','KUNNR','AEDAT','KVGR1','KVGR2','KVGR3','KVGR4','KVGR5',
            'KOKRS','KKBER','KNKLI','SBGRP','CTLPC','CMFRE','CMNUP','CMNGV',
            'AMTBL','ABRVW','VGBEL','BUKRS_VF','FMBDAT','QMNUM','AUFNR',
        ], 
        'rename_map': {
            'VBELN':    'Sales_Order',            'ERDAT': 'Created_On',
            'ERZET':    'Time',                   'ERNAM': 'Created_By',
            'AUDAT':    'Document_Date',          'VBTYP': 'SD_Document_Categ',
            'AUART':    'Sales_Document_Type',    'AUTLF': 'Complete_Delivery',
            'AUGRU':    'Order_Reason',            'LIFSK': 'Delivery_Block',
            'FAKSK':    'Billing_Block',           'NETWR': 'Net_Value',
            'WAERK':    'Document_Currency',       'VKORG': 'Sales_Organization',
            'VTWEG':    'Distribution_Channel',   'SPART': 'Division',
            'VKGRP':    'Sales_Group',             'VKBUR': 'Sales_Office',
            'KNUMV':    'Doc_Condition_No',        'VDATU': 'Requested_Deliv_Date',
            'VSBED':    'Shipping_Conditions',    'FKARA': 'Order_Relbilltype',
            'BSTNK':    'Purchase_Order_No',      'BSARK': 'Purchase_Order_Type',
            'BSTDK':    'Purchase_Order_Date',    'KUNNR': 'Sold_To_Party',
            'AEDAT':    'Changed_On',             'KVGR1': 'Customer_Group_1',
            'KVGR2':    'Customer_Group_2',       'KVGR3': 'Customer_Group_3',
            'KVGR4':    'Customer_Group_4',       'KVGR5': 'Customer_Group_5',
            'KOKRS':    'Controlling_Area',       'KKBER': 'Credit_Control_Area',
            'KNKLI':    'Credit_Account',         'SBGRP': 'Credit_Repgroup',
            'CTLPC':    'Risk_Category',          'CMFRE': 'Release_Date',
            'CMNUP':    'Next_Check',             'CMNGV': 'Next_Date',
            'AMTBL':    'Rel_Credit_Value',       'ABRVW': 'Usage',
            'VGBEL':    'Reference_Document',     'BUKRS_VF': 'CCode_To_Be_Billed',
            'FMBDAT':   'Material_Avail_Date',    'QMNUM': 'Notification',
            'AUFNR':    'Order',
        },
        'desc_joins': [
            {'desc_table': 'TVAKT',  'join_key': 'Sales_Document_Type', 'desc_key': 'AUART', 'desc_col': 'BEZEI', 'alias': 'Sales_Document_Type_Desc'},
            {'desc_table': 'TVAUT',  'join_key': 'Order_Reason',        'desc_key': 'AUGRU', 'desc_col': 'BEZEI', 'alias': 'Order_Reason_Desc'},
            {'desc_table': 'TVKOT',  'join_key': 'Sales_Organization',  'desc_key': 'VKORG', 'desc_col': 'VTEXT', 'alias': 'Sales_Organization_Name'},
            {'desc_table': 'TSPAT',  'join_key': 'Division',            'desc_key': 'SPART', 'desc_col': 'VTEXT', 'alias': 'Division_Name'},
            {'desc_table': 'TVKBT',  'join_key': 'Sales_Office',        'desc_key': 'VKBUR', 'desc_col': 'BEZEI', 'alias': 'Sales_Office_Name'},
            {'desc_table': 'TVSBT',  'join_key': 'Shipping_Conditions', 'desc_key': 'VSBED', 'desc_col': 'VTEXT', 'alias': 'Shipping_Conditions_Desc'},
            {'desc_table': 'TVFKT',  'join_key': 'Order_Relbilltype',   'desc_key': 'FKART', 'desc_col': 'VTEXT', 'alias': 'Order_Relbilltype_Desc'},
            {'desc_table': 'T176T',  'join_key': 'Purchase_Order_Type', 'desc_key': 'BSARK', 'desc_col': 'VTEXT', 'alias': 'Purchase_Order_Type_Desc'},
            {'desc_table': 'KNA1',   'join_key': 'Sold_To_Party',       'desc_key': 'Customer', 'desc_col': 'Name', 'alias': 'Sold_To_Party_Name'},
            {'desc_table': 'TVV1T',  'join_key': 'Customer_Group_1',    'desc_key': 'KVGR1', 'desc_col': 'BEZEI', 'alias': 'Customer_Group_1_Name'},
            {'desc_table': 'TVV2T',  'join_key': 'Customer_Group_2',    'desc_key': 'KVGR2', 'desc_col': 'BEZEI', 'alias': 'Customer_Group_2_Name'},
            {'desc_table': 'TVV3T',  'join_key': 'Customer_Group_3',    'desc_key': 'KVGR3', 'desc_col': 'BEZEI', 'alias': 'Customer_Group_3_Name'},
            {'desc_table': 'TVV4T',  'join_key': 'Customer_Group_4',    'desc_key': 'KVGR4', 'desc_col': 'BEZEI', 'alias': 'Customer_Group_4_Name'},
            {'desc_table': 'TVV5T',  'join_key': 'Customer_Group_5',    'desc_key': 'KVGR5', 'desc_col': 'BEZEI', 'alias': 'Customer_Group_5_Name'},
            {'desc_table': 'T014T',  'join_key': 'Credit_Control_Area', 'desc_key': 'KKBER', 'desc_col': 'KKBTX', 'alias': 'Credit_Control_Area_Name'},
            {'desc_table': 'T024B',  'join_key': 'Credit_Repgroup',     'desc_key': 'SBGRP', 'desc_col': 'STEXT', 'alias': 'Credit_Repgroup_Name'},
            {'desc_table': 'T691T',  'join_key': 'Risk_Category',       'desc_key': 'CTLPC', 'desc_col': 'RTEXT', 'alias': 'Risk_Category_Name'},
            {'desc_table': 'TVLVT',  'join_key': 'Usage',               'desc_key': 'ABRVW', 'desc_col': 'BEZEI', 'alias': 'Usage_Name'},
            {'desc_table': 'T001',   'join_key': 'CCode_To_Be_Billed',  'desc_key': 'Company_Code', 'desc_col': 'Company_Code_Name', 'alias': 'CCode_To_Be_Billed_Name'},
            {'desc_table': 'AUFK',   'join_key': 'Order',               'desc_key': 'AUFNR', 'desc_col': 'KTEXT', 'alias': 'Order_Name'},
        ],
        'sk_joins': [
            {'src_table': 'KNA1', 'join_key': 'Sold_To_Party', 'src_key': 'Customer', 'sk_col': 'Customer_SK'},
        ],
        'id_cols': [
            {'col': 'Sales_Organization_ID', 'sources': ['Sales_Organization', 'Sales_Organization_Name']},
            {'col': 'Division_ID',           'sources': ['Division',           'Division_Name']},
            {'col': 'Sales_Office_ID',       'sources': ['Sales_Office',       'Sales_Office_Name']},
            {'col': 'Sold_To_Party_ID',      'sources': ['Sold_To_Party',      'Sold_To_Party_Name']},
            {'col': 'Customer_Group_1_ID',   'sources': ['Customer_Group_1',   'Customer_Group_1_Name']},
            {'col': 'Customer_Group_2_ID',   'sources': ['Customer_Group_2',   'Customer_Group_2_Name']},
            {'col': 'Customer_Group_3_ID',   'sources': ['Customer_Group_3',   'Customer_Group_3_Name']},
            {'col': 'Customer_Group_4_ID',   'sources': ['Customer_Group_4',   'Customer_Group_4_Name']},
            {'col': 'Customer_Group_5_ID',   'sources': ['Customer_Group_5',   'Customer_Group_5_Name']},
        ],
        'lzero_cols': ['Sales_Order', 'Sold_To_Party'],
        'source_lh_key': 'SOURCE_LH_ABFSS',
        'enrich': [
            {'type': 'xrate', 'currency_col': 'Document_Currency', 'date_col': 'Created_On',
             'amount_cols': ['Net_Value']},
        ],
    },

    # ── VBAP — Sales Document Item ────────────────────────────────────────────
    'VBAP': {
        'primary_keys': ['VBELN', 'POSNR'],
        'sk_col':       'Sales_Order_Item_SK',
        'gold_name':    'Fact_Sales_Doc_Item',
        'silver_cols':  [
            'VBELN','POSNR','MATNR','CHARG','MATKL','ARKTX','PSTYV','POSAR',
            'LFREL','FKREL','UEPOS','ABGRU','PRODH','MEINS','VKAUS','GRKOR',
            'FAKSP','SPART','GSBER','WAERK','KWMENG','LSMENG','KBMENG','KLMENG',
            'VRKME','UMVKZ','UMVKN','NETWR','BRGEW','NTGEW','GEWEI','VOLUM',
            'VOLEH','LPRIO','WERKS','LGORT','VSTEL','ROUTE','AWAHR','ERDAT',
            'ERZET','ERNAM','TAXM1','TAXM2','NETPR','KPEIN','KMEIN','SHKZG',
            'SKTOF','MTVFP','SUMBD','KONDM','PRSOK','LFMNG','AEDAT','EAN11',
            'PRCTR','MVGR1','MVGR2','MVGR3','MVGR4','MVGR5','BEDAE','CMPRE',
            'MWSBP','BERID',
        ],
        'rename_map': {
            'VBELN':  'Sales_Order',               'POSNR': 'Item',
            'MATNR':  'Material',                  'CHARG': 'Batch',
            'MATKL':  'Material_Group',            'ARKTX': 'Description',
            'PSTYV':  'Item_Category',             'POSAR': 'Item_Type',
            'LFREL':  'Itm_Relev_For_Deliv',       'FKREL': 'Relevant_For_Billing',
            'UEPOS':  'Higher_Level_Item',         'ABGRU': 'Reason_For_Rejection',
            'PRODH':  'Product_Hierarchy',         'MEINS': 'Base_Unit_Of_Measure',
            'VKAUS':  'Usage',                     'GRKOR': 'Delivery_Group',
            'FAKSP':  'Billing_Block',             'SPART': 'Division',
            'GSBER':  'Business_Area',             'WAERK': 'Document_Currency',
            'KWMENG': 'Order_Quantity',            'LSMENG': 'Required_Deliv_Qty',
            'KBMENG': 'Cumulconfirmed_Qty',        'KLMENG': 'Cumulconfirmed_Qty_dup2',
            'VRKME':  'Sales_Unit',                'UMVKZ': 'Numerator',
            'UMVKN':  'Denominator',               'NETWR': 'Net_Value',
            'BRGEW':  'Gross_Weight',              'NTGEW': 'Net_Weight',
            'GEWEI':  'Weight_Unit',               'VOLUM': 'Volume',
            'VOLEH':  'Volume_Unit',               'LPRIO': 'Delivery_Priority',
            'WERKS':  'Plant',                     'LGORT': 'Storage_Location',
            'VSTEL':  'Shipping_PointReceiving_Pt','ROUTE': 'Route',
            'AWAHR':  'Order_Probability',         'ERDAT': 'Created_On',
            'ERZET':  'Time',                      'ERNAM': 'Created_By',
            'TAXM1':  'Tax_Classification',        'TAXM2': 'Tax_Classification_dup2',
            'NETPR':  'Net_Price',                 'KPEIN': 'Pricing_Unit',
            'KMEIN':  'Unit_Of_Measure',           'SHKZG': 'Returns',
            'SKTOF':  'Cash_Discount',             'MTVFP': 'Availability_Check',
            'SUMBD':  'Requirements_Totals',       'KONDM': 'Material_Pricing_Grp',
            'PRSOK':  'Pricing',                   'LFMNG': 'Minimum_Delivery_Qty',
            'AEDAT':  'Changed_On',                'EAN11': 'EANUPC',
            'PRCTR':  'Profit_Center',             'MVGR1': 'Material_Group_1',
            'MVGR2':  'Material_Group_2',          'MVGR3': 'Material_Group_3',
            'MVGR4':  'Material_Group_4',          'MVGR5': 'Material_Group_5',
            'BEDAE':  'Requirements_Type',         'CMPRE': 'Credit_Price',
            'MWSBP':  'Tax_Amount',                'BERID': 'MRP_Area',
        },
        'desc_joins': [
            {'desc_table': 'MAKT',   'join_key': 'Material',                    'desc_key': 'MATNR',     'desc_col': 'MAKTX', 'alias': 'Material_Desc'},
            {'desc_table': 'T179T',  'join_key': 'Product_Hierarchy',           'desc_key': 'PRODH',     'desc_col': 'VTEXT', 'alias': 'Product_Hierarchy_Desc'},
            {'desc_table': 'TVLVT',  'join_key': 'Usage',                       'desc_key': 'ABRVW',     'desc_col': 'BEZEI', 'alias': 'Usage_Desc'},
            {'desc_table': 'TVFST',  'join_key': 'Billing_Block',               'desc_key': 'FAKSP',     'desc_col': 'VTEXT', 'alias': 'Billing_Block_Desc'},
            {'desc_table': 'TSPAT',  'join_key': 'Division',                    'desc_key': 'SPART',     'desc_col': 'VTEXT', 'alias': 'Division_Name'},
            {'desc_table': 'T001L',  'join_keys': ['Plant', 'Storage_Location'], 'desc_keys': ['WERKS', 'LGORT'], 'desc_col': 'LGOBE', 'alias': 'Storage_Location_Desc'},
            {'desc_table': 'TVST',   'join_key': 'Shipping_PointReceiving_Pt',  'desc_key': 'VSTEL',     'desc_col': 'VTEXT', 'alias': 'Shipping_Point_Desc'},
            {'desc_table': 'TVROT',  'join_key': 'Route',                       'desc_key': 'ROUTE',     'desc_col': 'BEZEI', 'alias': 'Route_Desc'},
            {'desc_table': 'TMVFT',  'join_key': 'Availability_Check',          'desc_key': 'MTVFP',     'desc_col': 'BEZEI', 'alias': 'Availability_Check_Desc'},
            {'desc_table': 'T178T',  'join_key': 'Material_Pricing_Grp',        'desc_key': 'KONDM',     'desc_col': 'VTEXT', 'alias': 'Material_Pricing_Grp_Desc'},
            {'desc_table': 'CEPCT',  'join_key': 'Profit_Center',               'desc_key': 'PRCTR',     'desc_col': 'MCTXT', 'alias': 'Profit_Center_Name'},
            {'desc_table': 'TVM1T',  'join_key': 'Material_Group_1',            'desc_key': 'MVGR1',     'desc_col': 'BEZEI', 'alias': 'Material_Group_1_Name'},
            {'desc_table': 'TVM2T',  'join_key': 'Material_Group_2',            'desc_key': 'MVGR2',     'desc_col': 'BEZEI', 'alias': 'Material_Group_2_Name'},
            {'desc_table': 'TVM3T',  'join_key': 'Material_Group_3',            'desc_key': 'MVGR3',     'desc_col': 'BEZEI', 'alias': 'Material_Group_3_Name'},
            {'desc_table': 'TVM4T',  'join_key': 'Material_Group_4',            'desc_key': 'MVGR4',     'desc_col': 'BEZEI', 'alias': 'Material_Group_4_Name'},
            {'desc_table': 'TVM5T',  'join_key': 'Material_Group_5',            'desc_key': 'MVGR5',     'desc_col': 'BEZEI', 'alias': 'Material_Group_5_Name'},
            {'desc_table': 'T459W',  'join_key': 'Requirements_Type',           'desc_key': 'BEDAE',     'desc_col': 'BDTXT', 'alias': 'Requirements_Type_Desc'},
            {'desc_table': 'T001W',  'join_key': 'Plant',                       'desc_key': 'Plant',     'desc_col': 'Plant_Name', 'alias': 'Plant_Name'},
        ],
        'sk_joins': [
            {'src_table': 'MARA',  'join_key': 'Material', 'src_key': 'Material', 'sk_col': 'Material_SK'},
            {'src_table': 'T001W', 'join_key': 'Plant',    'src_key': 'Plant',    'sk_col': 'Plant_SK'},
        ],
        'id_cols': [
            {'col': 'Material_ID',          'sources': ['Material',          'Material_Desc']},
            {'col': 'Storage_Location_ID',  'sources': ['Storage_Location',  'Storage_Location_Desc']},
            {'col': 'Product_Hierarchy_ID', 'sources': ['Product_Hierarchy', 'Product_Hierarchy_Desc']},
            {'col': 'Division_ID',          'sources': ['Division',          'Division_Name']},
            {'col': 'Profit_Center_ID',     'sources': ['Profit_Center',     'Profit_Center_Name']},
            {'col': 'Material_Group_1_ID',  'sources': ['Material_Group_1',  'Material_Group_1_Name']},
            {'col': 'Material_Group_2_ID',  'sources': ['Material_Group_2',  'Material_Group_2_Name']},
            {'col': 'Material_Group_3_ID',  'sources': ['Material_Group_3',  'Material_Group_3_Name']},
            {'col': 'Material_Group_4_ID',  'sources': ['Material_Group_4',  'Material_Group_4_Name']},
            {'col': 'Material_Group_5_ID',  'sources': ['Material_Group_5',  'Material_Group_5_Name']},
        ],
        'lzero_cols': ['Sales_Order', 'Item', 'Profit_Center'],
        'source_lh_key': 'SOURCE_LH_ABFSS',
        'enrich': [
            {'type': 'xrate', 'currency_col': 'Document_Currency', 'date_col': 'Created_On',
             'amount_cols': ['Net_Value']},
            {'type': 'unit_conv', 'qty_col': 'Net_Weight', 'uom_col': 'Weight_Unit',
             'primary_unit': 'KG', 'conv_unit': 'LB'},
            {'type': 'unit_conv', 'qty_col': 'Net_Weight', 'uom_col': 'Weight_Unit',
             'primary_unit': 'LB', 'conv_unit': 'KG'},
        ],
    },

    # ── VBEP — Schedule Lines ─────────────────────────────────────────────────
    'VBEP': {
        'primary_keys': ['VBELN', 'POSNR', 'ETENR'],
        'sk_col':       'Sales_Schedule_SK',
        'gold_name':    'Fact_Schedule_Line',
        'silver_cols':  [
            'VBELN','POSNR','ETENR','ETTYP','LFREL','EDATU','WMENG','BMENG',
            'VRKME','BDART','MEINS','TDDAT','MBDAT','LDDAT','WADAT','CMENG',
            'LIFSP','BWART',
        ],
        'rename_map': {
            'VBELN':  'Sales_Order',           'POSNR': 'Item',
            'ETENR':  'Schedule_Line',         'ETTYP': 'Schedline_Category',
            'LFREL':  'Itm_Relev_For_Deliv',   'EDATU': 'Delivery_Date',
            'WMENG':  'Order_Quantity',         'BMENG': 'Confirmed_Quantity',
            'VRKME':  'Sales_Unit',            'BDART': 'Requirement_Type',
            'MEINS':  'Base_Unit_Of_Measure',  'TDDAT': 'Transptn_Plang_Date',
            'MBDAT':  'Material_Avail_Date',   'LDDAT': 'Loading_Date',
            'WADAT':  'Goods_Issue_Date',      'CMENG': 'Corr_Qty',
            'LIFSP':  'Delivery_Block',        'BWART': 'Movement_Type',
        },
        'desc_joins': [
            {'desc_table': 'TVEPT',  'join_key': 'Schedline_Category', 'desc_key': 'ETTYP', 'desc_col': 'VTEXT', 'alias': 'Schedline_Category_Desc'},
            {'desc_table': 'T006A',  'join_key': 'Base_Unit_Of_Measure','desc_key': 'MSEHI', 'desc_col': 'MSEHT', 'alias': 'Base_UoM_Desc'},
            {'desc_table': 'TVLST',  'join_key': 'Delivery_Block',     'desc_key': 'LIFSP', 'desc_col': 'VTEXT', 'alias': 'Delivery_Block_Desc'},
            {'desc_table': 'T156HT', 'join_key': 'Movement_Type',      'desc_key': 'BWART', 'desc_col': 'BTEXT', 'alias': 'Movement_Type_Desc'},
        ],
        'sk_joins': [],
        'id_cols': [
            {'col': 'Movement_Type_ID', 'sources': ['Movement_Type', 'Movement_Type_Desc']},
        ],
        'lzero_cols': ['Sales_Order', 'Item', 'Schedule_Line'],
        'source_lh_key': 'SOURCE_LH_ABFSS',
        'enrich': [
            {'type': 'unit_conv', 'qty_col': 'Order_Quantity', 'uom_col': 'Sales_Unit',
             'primary_unit': 'KG', 'conv_unit': 'LB'},
            {'type': 'unit_conv', 'qty_col': 'Order_Quantity', 'uom_col': 'Sales_Unit',
             'primary_unit': 'LB', 'conv_unit': 'KG'},
        ],
    },

    # ── LIKP — Delivery Header ────────────────────────────────────────────────
    'LIKP': {
        'primary_keys': ['VBELN'],
        'sk_col':       'Delivery_SK',
        'gold_name':    'Fact_Delivery_Item',
        'silver_cols':  [
            'VBELN','ERNAM','ERZET','ERDAT','BZIRK','VSTEL','VKORG','LFART',
            'AUTLF','KZAZU','WADAT','LDDAT','TDDAT','LFDAT','KODAT','ABLAD',
            'INCO1','INCO2','ROUTE','FAKSK','LIFSK','VBTYP','KNFAK','LPRIO',
            'VSBED','KUNNR','KUNAG','KDGRP','BTGEW','NTGEW','GEWEI','VOLUM',
            'VOLEH','GRULG','TRAGR','FKARV','FKDAT','PERFK','KALSM','WAERK',
            'STWAE','AENAM','AEDAT','LGNUM','KKBER','KNKLI','CTLPC','CMWAE',
            'AMTBL','LIFNR','BLDAT','WADAT_IST','TRSPG','NETWR','AULWE',
            'WERKS','KOUHR','TDUHR','LDUHR','WAUHR','LGBZO','TSEGTP',
            'TZONIS','TZONRC','VSART',
        ],
        'rename_map': {
            'VBELN':    'Delivery',                    'ERNAM': 'Created_By',
            'ERZET':    'Time',                        'ERDAT': 'Created_On',
            'BZIRK':    'Sales_District',              'VSTEL': 'Shipping_PointReceiving_Pt',
            'VKORG':    'Sales_Organization',          'LFART': 'Delivery_Type',
            'AUTLF':    'Complete_Delivery',           'KZAZU': 'Order_Combination',
            'WADAT':    'Pland_Gds_Mvmnt_Date',        'LDDAT': 'Loading_Date',
            'TDDAT':    'Transptn_Plang_Date',         'LFDAT': 'Delivery_Date',
            'KODAT':    'Picking_Date',                'ABLAD': 'Unloading_Point',
            'INCO1':    'Incoterms',                   'INCO2': 'Incoterms_Part_2',
            'ROUTE':    'Route',                       'FAKSK': 'Billing_Block',
            'LIFSK':    'Delivery_Block',              'VBTYP': 'SD_Document_Categ',
            'KNFAK':    'Factory_Calendar',            'LPRIO': 'Delivery_Priority',
            'VSBED':    'Shipping_Conditions',         'KUNNR': 'Ship_To_Party',
            'KUNAG':    'Sold_To_Party',               'KDGRP': 'Customer_Group',
            'BTGEW':    'Total_Weight',                'NTGEW': 'Net_Weight',
            'GEWEI':    'Weight_Unit',                 'VOLUM': 'Volume',
            'VOLEH':    'Volume_Unit',                 'GRULG': 'Weight_Group',
            'TRAGR':    'Transportation_Group',        'FKARV': 'Dlv_Relbilling_Type',
            'FKDAT':    'Billing_Date',                'PERFK': 'Invoicing_Dates',
            'KALSM':    'Procedure',                   'WAERK': 'Document_Currency',
            'STWAE':    'Statistics_Currency',         'AENAM': 'Changed_By',
            'AEDAT':    'Changed_On',                  'LGNUM': 'Warehouse_Number',
            'KKBER':    'Credit_Control_Area',         'KNKLI': 'Credit_Account',
            'CTLPC':    'Risk_Category',               'CMWAE': 'Currency',
            'AMTBL':    'Rel_Credit_Value',            'LIFNR': 'Supplier',
            'BLDAT':    'Document_Date',               'WADAT_IST': 'Actual_GI_Date',
            'TRSPG':    'ShipmentBlockReason',         'NETWR': 'Net_Value',
            'AULWE':    'Route_Schedule',              'WERKS': 'Receiving_Plant',
            'KOUHR':    'Picking_Time',                'TDUHR': 'Transp_Plan_Time',
            'LDUHR':    'Loading_Time',                'WAUHR': 'Goods_Issue_Time',
            'LGBZO':    'Staging_Area',                'TSEGTP': 'Template',
            'TZONIS':   'Del_Loc_Time_Zone',           'TZONRC': 'Rec_Loc_Time_Zone',
            'VSART':    'Shipping_Type',
        },
        'desc_joins': [
            {'desc_table': 'T171T',  'join_key': 'Sales_District',         'desc_key': 'BZIRK', 'desc_col': 'BZTXT', 'alias': 'Sales_District_Name'},
            {'desc_table': 'TVSTT',  'join_key': 'Shipping_PointReceiving_Pt', 'desc_key': 'VSTEL', 'desc_col': 'VTEXT', 'alias': 'Shipping_Point_Name'},
            {'desc_table': 'TVKOT',  'join_key': 'Sales_Organization',     'desc_key': 'VKORG', 'desc_col': 'VTEXT', 'alias': 'Sales_Organization_Name'},
            {'desc_table': 'TVLKT',  'join_key': 'Delivery_Type',          'desc_key': 'LFART', 'desc_col': 'VTEXT', 'alias': 'Delivery_Type_Desc'},
            {'desc_table': 'TINCT',  'join_key': 'Incoterms',              'desc_key': 'INCO1', 'desc_col': 'BEZEI', 'alias': 'Incoterms_Desc'},
            {'desc_table': 'TVFST',  'join_key': 'Billing_Block',          'desc_key': 'FAKSP', 'desc_col': 'VTEXT', 'alias': 'Billing_Block_Desc'},
            {'desc_table': 'TVLST',  'join_key': 'Delivery_Block',         'desc_key': 'LIFSP', 'desc_col': 'VTEXT', 'alias': 'Delivery_Block_Desc'},
            {'desc_table': 'TPRIT',  'join_key': 'Delivery_Priority',      'desc_key': 'LPRIO', 'desc_col': 'BEZEI', 'alias': 'Delivery_Priority_Desc'},
            {'desc_table': 'TVSBT',  'join_key': 'Shipping_Conditions',    'desc_key': 'VSBED', 'desc_col': 'VTEXT', 'alias': 'Shipping_Conditions_Desc'},
            {'desc_table': 'KNA1',   'join_key': 'Ship_To_Party',          'desc_key': 'Customer', 'desc_col': 'Name', 'alias': 'Ship_To_Party_Name'},
            {'desc_table': 'KNA1',   'join_key': 'Sold_To_Party',          'desc_key': 'Customer', 'desc_col': 'Name', 'alias': 'Sold_To_Party_Name'},
            {'desc_table': 'T151T',  'join_key': 'Customer_Group',         'desc_key': 'KDGRP', 'desc_col': 'KTEXT', 'alias': 'Customer_Group_Name'},
            {'desc_table': 'TTGRT',  'join_key': 'Transportation_Group',   'desc_key': 'TRAGR', 'desc_col': 'VTEXT', 'alias': 'Transportation_Group_Desc'},
            {'desc_table': 'TVFKT',  'join_key': 'Dlv_Relbilling_Type',    'desc_key': 'FKART', 'desc_col': 'VTEXT', 'alias': 'Dlv_Relbilling_Type_Desc'},
            {'desc_table': 'T300T',  'join_key': 'Warehouse_Number',       'desc_key': 'LGNUM', 'desc_col': 'LNUMT', 'alias': 'Warehouse_Number_Name'},
            {'desc_table': 'T014T',  'join_key': 'Credit_Control_Area',    'desc_key': 'KKBER', 'desc_col': 'KKBTX', 'alias': 'Credit_Control_Area_Name'},
            {'desc_table': 'LFA1',   'join_key': 'Supplier',               'desc_key': 'Supplier', 'desc_col': 'Name', 'alias': 'Supplier_Name'},
            {'desc_table': 'TTSGT',  'join_key': 'ShipmentBlockReason',    'desc_key': 'TRSPG', 'desc_col': 'BEZEI', 'alias': 'ShipmentBlockReason_Desc'},
            {'desc_table': 'T001W',  'join_key': 'Receiving_Plant',        'desc_key': 'Plant', 'desc_col': 'Plant_Name', 'alias': 'Receiving_Plant_Name'},
            {'desc_table': 'T30CT',  'join_key': 'Staging_Area',           'desc_key': 'LGBZO', 'desc_col': 'LBZOT', 'alias': 'Staging_Area_Desc'},
            {'desc_table': 'T173T',  'join_key': 'Shipping_Type',          'desc_key': 'VSART', 'desc_col': 'BEZEI', 'alias': 'Shipping_Type_Desc'},
        ],
        'sk_joins': [
            {'src_table': 'KNA1', 'join_key': 'Ship_To_Party', 'src_key': 'Customer', 'sk_col': 'Customer_SK'},
        ],
        'id_cols': [
            {'col': 'Sales_District_ID',      'sources': ['Sales_District',      'Sales_District_Name']},
            {'col': 'Sales_Organization_ID',  'sources': ['Sales_Organization',  'Sales_Organization_Name']},
            {'col': 'Ship_To_Party_ID',       'sources': ['Ship_To_Party',       'Ship_To_Party_Name']},
            {'col': 'Sold_To_Party_ID',       'sources': ['Sold_To_Party',       'Sold_To_Party_Name']},
            {'col': 'Supplier_ID',            'sources': ['Supplier',            'Supplier_Name']},
        ],
        'lzero_cols': ['Delivery'],
        'source_lh_key': 'SOURCE_LH_ABFSS',
        'enrich': [
            {'type': 'xrate', 'currency_col': 'Document_Currency', 'date_col': 'Created_On',
             'amount_cols': ['Net_Value']},
            {'type': 'unit_conv', 'qty_col': 'Net_Weight', 'uom_col': 'Weight_Unit',
             'primary_unit': 'KG', 'conv_unit': 'LB'},
            {'type': 'unit_conv', 'qty_col': 'Net_Weight', 'uom_col': 'Weight_Unit',
             'primary_unit': 'LB', 'conv_unit': 'KG'},
        ],
    },

    # ── LIPS — Delivery Item ──────────────────────────────────────────────────
    'LIPS': {
        'primary_keys': ['VBELN', 'POSNR'],
        'sk_col':       'Delivery_Item_SK',
        'gold_name':    'Fact_Delivery_Item',
        'silver_cols':  [
            'VBELN','POSNR','PSTYV','ERNAM','ERZET','ERDAT','MATNR','MATWA',
            'MATKL','WERKS','LGORT','CHARG','PRODH','LFIMG','MEINS','VRKME',
            'UMVKZ','UMVKN','NTGEW','BRGEW','GEWEI','VOLUM','VOLEH','KZTLF',
            'MBDAT','LGMNG','ARKTX','VGBEL','VGPOS','KCMENG','KCMENGVME',
            'UPFLU','UEPOS','FKREL','LADGR','TRAGR','KOMKZ','LGNUM','BWART',
            'BDART','PLART','MTART','SUMBD','MTVFP','GSBER','VKBUR','VKGRP',
            'VTWEG','SPART','WAVWR','KZWI1','SOBKZ','AEDAT','EAN11',
            'KVGR1','KVGR2','KVGR3','KVGR4','KVGR5',
            'MVGR1','MVGR2','MVGR3','MVGR4','MVGR5',
            'VPZUO','VGTYP','KOSTL','KOKRS','PRCTR',
            'BEDAR_LF','MAGRV','SHKZG','KZUMW','MFRGR','ORMNG',
        ],
        'rename_map': {
            'VBELN':    'Delivery',                    'POSNR': 'Delivery_Item',
            'PSTYV':    'Item_Category',               'ERNAM': 'Created_By',
            'ERZET':    'Time',                        'ERDAT': 'Created_On',
            'MATNR':    'Material',                    'MATWA': 'Material_Entered',
            'MATKL':    'Material_Group',              'WERKS': 'Plant',
            'LGORT':    'Storage_Location',            'CHARG': 'Batch',
            'PRODH':    'Product_Hierarchy',           'LFIMG': 'Delivery_Quantity',
            'MEINS':    'Base_Unit_Of_Measure',        'VRKME': 'Sales_Unit',
            'UMVKZ':    'Numerator',                   'UMVKN': 'Denominator',
            'NTGEW':    'Net_Weight',                  'BRGEW': 'Gross_Weight',
            'GEWEI':    'Weight_Unit',                 'VOLUM': 'Volume',
            'VOLEH':    'Volume_Unit',                 'KZTLF': 'Partial_Delivery_Item_Level',
            'MBDAT':    'Material_Avail_Date',         'LGMNG': 'Actual_Delivery_Qty',
            'ARKTX':    'Description',                 'VGBEL': 'Reference_Document',
            'VGPOS':    'Reference_Item',              'KCMENG': 'Cumul_Batch_Qty_Split_Stckunit',
            'KCMENGVME':'Cumul_Batch_Qty_Split_Salesunit','UPFLU': 'Update_Document_Flow',
            'UEPOS':    'Higher_Level_Item',           'FKREL': 'Relevant_For_Billing',
            'LADGR':    'Loading_Group',               'TRAGR': 'Transportation_Group',
            'KOMKZ':    'Picking_Indicator',           'LGNUM': 'Warehouse_Number',
            'BWART':    'Movement_Type',               'BDART': 'Requirement_Type',
            'PLART':    'Planning_Type',               'MTART': 'Material_Type',
            'SUMBD':    'Requirements_Totals',         'MTVFP': 'Availability_Check',
            'GSBER':    'Business_Area',               'VKBUR': 'Sales_Office',
            'VKGRP':    'Sales_Group',                 'VTWEG': 'Distribution_Channel',
            'SPART':    'Division',                    'WAVWR': 'Cost',
            'KZWI1':    'Subtotal_1',                  'SOBKZ': 'Special_Stock',
            'AEDAT':    'Changed_On',                  'EAN11': 'EANUPC',
            'KVGR1':    'Customer_Group_1',            'KVGR2': 'Customer_Group_2',
            'KVGR3':    'Customer_Group_3',            'KVGR4': 'Customer_Group_4',
            'KVGR5':    'Customer_Group_5',            'MVGR1': 'Material_Group_1',
            'MVGR2':    'Material_Group_2',            'MVGR3': 'Material_Group_3',
            'MVGR4':    'Material_Group_4',            'MVGR5': 'Material_Group_5',
            'VPZUO':    'Allocation_Indicat',          'VGTYP': 'SD_Document_Categ',
            'KOSTL':    'Cost_Center',                 'KOKRS': 'Controlling_Area',
            'PRCTR':    'Profit_Center',               'BEDAR_LF': 'Requirements_Class',
            'MAGRV':    'Matl_Grp_PackMatls',          'SHKZG': 'Returns',
            'KZUMW':    'Environmentally_Rlvt',        'MFRGR': 'Material_Freight_Grp',
            'ORMNG':    'Delivery_Quantity_dup2',
        },
        'desc_joins': [
            {'desc_table': 'TVAPT',  'join_key': 'Item_Category',         'desc_key': 'PSTYV', 'desc_col': 'VTEXT', 'alias': 'Item_Category_Desc'},
            {'desc_table': 'MAKT',   'join_key': 'Material',              'desc_key': 'MATNR',    'desc_col': 'MAKTX', 'alias': 'Material_Desc'},
            {'desc_table': 'T023T',  'join_key': 'Material_Group',        'desc_key': 'MATKL', 'desc_col': 'WGBEZ', 'alias': 'Material_Group_Desc'},
            {'desc_table': 'T001W',  'join_key': 'Plant',                 'desc_key': 'Plant', 'desc_col': 'Plant_Name', 'alias': 'Plant_Name'},
            {'desc_table': 'T001L',  'join_keys': ['Plant', 'Storage_Location'], 'desc_keys': ['WERKS', 'LGORT'], 'desc_col': 'LGOBE', 'alias': 'Storage_Location_Desc'},
            {'desc_table': 'T179T',  'join_key': 'Product_Hierarchy',     'desc_key': 'PRODH', 'desc_col': 'VTEXT', 'alias': 'Product_Hierarchy_Desc'},
            {'desc_table': 'TLGRT',  'join_key': 'Loading_Group',         'desc_key': 'LADGR', 'desc_col': 'VTEXT', 'alias': 'Loading_Group_Desc'},
            {'desc_table': 'TTGRT',  'join_key': 'Transportation_Group',  'desc_key': 'TRAGR', 'desc_col': 'VTEXT', 'alias': 'Transportation_Group_Desc'},
            {'desc_table': 'T156HT', 'join_key': 'Movement_Type',         'desc_key': 'BWART', 'desc_col': 'BTEXT', 'alias': 'Movement_Type_Desc'},
            {'desc_table': 'T134T',  'join_key': 'Material_Type',         'desc_key': 'MTART', 'desc_col': 'MTBEZ', 'alias': 'Material_Type_Desc'},
            {'desc_table': 'TMVFT',  'join_key': 'Availability_Check',    'desc_key': 'MTVFP', 'desc_col': 'BEZEI', 'alias': 'Availability_Check_Desc'},
            {'desc_table': 'TGSBT',  'join_key': 'Business_Area',         'desc_key': 'GSBER', 'desc_col': 'GTEXT', 'alias': 'Business_Area_Desc'},
            {'desc_table': 'TVKBT',  'join_key': 'Sales_Office',          'desc_key': 'VKBUR', 'desc_col': 'BEZEI', 'alias': 'Sales_Office_Name'},
            {'desc_table': 'TSPAT',  'join_key': 'Division',              'desc_key': 'SPART', 'desc_col': 'VTEXT', 'alias': 'Division_Name'},
            {'desc_table': 'T148T',  'join_key': 'Special_Stock',         'desc_key': 'SOBKZ', 'desc_col': 'SOTXT', 'alias': 'Special_Stock_Desc'},
            {'desc_table': 'TVV1T',  'join_key': 'Customer_Group_1',      'desc_key': 'KVGR1', 'desc_col': 'BEZEI', 'alias': 'Customer_Group_1_Name'},
            {'desc_table': 'TVV2T',  'join_key': 'Customer_Group_2',      'desc_key': 'KVGR2', 'desc_col': 'BEZEI', 'alias': 'Customer_Group_2_Name'},
            {'desc_table': 'TVV3T',  'join_key': 'Customer_Group_3',      'desc_key': 'KVGR3', 'desc_col': 'BEZEI', 'alias': 'Customer_Group_3_Name'},
            {'desc_table': 'TVV4T',  'join_key': 'Customer_Group_4',      'desc_key': 'KVGR4', 'desc_col': 'BEZEI', 'alias': 'Customer_Group_4_Name'},
            {'desc_table': 'TVV5T',  'join_key': 'Customer_Group_5',      'desc_key': 'KVGR5', 'desc_col': 'BEZEI', 'alias': 'Customer_Group_5_Name'},
            {'desc_table': 'TVM1T',  'join_key': 'Material_Group_1',      'desc_key': 'MVGR1', 'desc_col': 'BEZEI', 'alias': 'Material_Group_1_Name'},
            {'desc_table': 'TVM2T',  'join_key': 'Material_Group_2',      'desc_key': 'MVGR2', 'desc_col': 'BEZEI', 'alias': 'Material_Group_2_Name'},
            {'desc_table': 'TVM3T',  'join_key': 'Material_Group_3',      'desc_key': 'MVGR3', 'desc_col': 'BEZEI', 'alias': 'Material_Group_3_Name'},
            {'desc_table': 'TVM4T',  'join_key': 'Material_Group_4',      'desc_key': 'MVGR4', 'desc_col': 'BEZEI', 'alias': 'Material_Group_4_Name'},
            {'desc_table': 'TVM5T',  'join_key': 'Material_Group_5',      'desc_key': 'MVGR5', 'desc_col': 'BEZEI', 'alias': 'Material_Group_5_Name'},
            {'desc_table': 'CEPCT',  'join_key': 'Profit_Center',         'desc_key': 'PRCTR', 'desc_col': 'MCTXT', 'alias': 'Profit_Center_Name'},
            {'desc_table': 'TVEGRT', 'join_key': 'Matl_Grp_PackMatls',    'desc_key': 'MAGRV', 'desc_col': 'BEZEI', 'alias': 'Matl_Grp_PackMatls_Desc'},
            {'desc_table': 'TMFGT',  'join_key': 'Material_Freight_Grp',  'desc_key': 'MFRGR', 'desc_col': 'BEZEI', 'alias': 'Material_Freight_Grp_Desc'},
        ],
        'sk_joins': [
            {'src_table': 'MARA',  'join_key': 'Material', 'src_key': 'Material', 'sk_col': 'Material_SK'},
            {'src_table': 'T001W', 'join_key': 'Plant',    'src_key': 'Plant',    'sk_col': 'Plant_SK'},
        ],
        'id_cols': [
            {'col': 'Material_ID',          'sources': ['Material',          'Material_Desc']},
            {'col': 'Plant_ID',             'sources': ['Plant',             'Plant_Name']},
            {'col': 'Storage_Location_ID',  'sources': ['Storage_Location',  'Storage_Location_Desc']},
            {'col': 'Product_Hierarchy_ID', 'sources': ['Product_Hierarchy', 'Product_Hierarchy_Desc']},
            {'col': 'Movement_Type_ID',     'sources': ['Movement_Type',     'Movement_Type_Desc']},
            {'col': 'Material_Type_ID',     'sources': ['Material_Type',     'Material_Type_Desc']},
            {'col': 'Division_ID',          'sources': ['Division',          'Division_Name']},
            {'col': 'Sales_Office_ID',      'sources': ['Sales_Office',      'Sales_Office_Name']},
            {'col': 'Profit_Center_ID',     'sources': ['Profit_Center',     'Profit_Center_Name']},
            {'col': 'Customer_Group_1_ID',  'sources': ['Customer_Group_1',  'Customer_Group_1_Name']},
            {'col': 'Customer_Group_2_ID',  'sources': ['Customer_Group_2',  'Customer_Group_2_Name']},
            {'col': 'Customer_Group_3_ID',  'sources': ['Customer_Group_3',  'Customer_Group_3_Name']},
            {'col': 'Customer_Group_4_ID',  'sources': ['Customer_Group_4',  'Customer_Group_4_Name']},
            {'col': 'Customer_Group_5_ID',  'sources': ['Customer_Group_5',  'Customer_Group_5_Name']},
            {'col': 'Material_Group_1_ID',  'sources': ['Material_Group_1',  'Material_Group_1_Name']},
            {'col': 'Material_Group_2_ID',  'sources': ['Material_Group_2',  'Material_Group_2_Name']},
            {'col': 'Material_Group_3_ID',  'sources': ['Material_Group_3',  'Material_Group_3_Name']},
            {'col': 'Material_Group_4_ID',  'sources': ['Material_Group_4',  'Material_Group_4_Name']},
            {'col': 'Material_Group_5_ID',  'sources': ['Material_Group_5',  'Material_Group_5_Name']},
        ],
        'lzero_cols': ['Delivery', 'Delivery_Item', 'Reference_Item', 'Profit_Center'],
        'source_lh_key': 'SOURCE_LH_ABFSS',
        'enrich': [
            {'type': 'unit_conv', 'qty_col': 'Net_Weight', 'uom_col': 'Weight_Unit',
             'primary_unit': 'KG', 'conv_unit': 'LB'},
            {'type': 'unit_conv', 'qty_col': 'Net_Weight', 'uom_col': 'Weight_Unit',
             'primary_unit': 'LB', 'conv_unit': 'KG'},
        ],
    },

}

BW_BACKLOG_TABLE  = 'TR_Backlog_2WEEKS'
MPG_MAPPING_TABLE = 'MAP_MPG_Sales_Org'

print(f'SO config loaded: {list(SD_TABLE_CONFIGS.keys())}')
print(f'Overwrite tables: {BW_BACKLOG_TABLE}, {MPG_MAPPING_TABLE}')

# %%
# ── SD-specific desc tables — Bronze ingestion ────────────────────────────────
# All stored flat at Tables/{name} in LH_SAP_DAB_BRZ_MD (no dbo schema prefix).
# source_lh_key = SOURCE_MD_LH_ABFSS → the MD source lakehouse.
# source_schema = ''                  → no dbo prefix; path = {SOURCE_MD_LH_ABFSS}/{table}.
#
# Bronze ingests all languages; SPRAS = 'EN' filtering happens at Silver desc_join time.
#
# Purple tables (not yet in source extract) are commented out.
# Uncomment each once confirmed available in LH_SAP_DAB_BRZ_MD.
# Purple: TVSBT, AUFK, T459W, TVLKT, TTGRT, T300T, TTSGT, T30CT, TGSBT, TVEGRT, TMFGT

SD_DESC_CONFIGS = {

    # ── Sales Order (VBAK) desc ───────────────────────────────────────────────
    'TVAKT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['AUART', 'SPRAS'],
              'silver_cols': ['AUART', 'SPRAS', 'BEZEI'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'TVAUT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['AUGRU', 'SPRAS'],
              'silver_cols': ['AUGRU', 'SPRAS', 'BEZEI'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # TVSBT — purple (not yet in source extract); uncomment when available
    # 'TVSBT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
    #           'primary_keys': ['VSBED', 'SPRAS'],
    #           'silver_cols': ['VSBED', 'SPRAS', 'VTEXT'],
    #           'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # Source columns: MANDT, SPRAS, FKART, VTEXT, SYSTEM (key field is FKART not FKARA)
    'TVFKT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['FKART', 'SPRAS'],
              'silver_cols': ['FKART', 'SPRAS', 'VTEXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'T176T': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['BSARK', 'SPRAS'],
              'silver_cols': ['BSARK', 'SPRAS', 'VTEXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'T014T': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['KKBER', 'SPRAS'],
              'silver_cols': ['KKBER', 'SPRAS', 'KKBTX'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # Source columns: MANDT, SBGRP, KKBER, STEXT, SMAIL, SYSTEM (no SPRAS — not language-dependent)
    'T024B': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['SBGRP', 'KKBER'],
              'silver_cols': ['SBGRP', 'KKBER', 'STEXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'T691T': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['KKBER', 'CTLPC', 'SPRAS'],
              'silver_cols': ['KKBER', 'CTLPC', 'SPRAS', 'RTEXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'TVLVT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['ABRVW', 'SPRAS'],
              'silver_cols': ['ABRVW', 'SPRAS', 'BEZEI'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # AUFK — purple (not yet in source extract); uncomment when available
    # 'AUFK':  {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
    #           'primary_keys': ['AUFNR'],
    #           'silver_cols': ['AUFNR', 'KTEXT', 'AUART'],
    #           'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # ── Sales Order Item (VBAP) desc ──────────────────────────────────────────
    'TVFST': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['FAKSP', 'SPRAS'],
              'silver_cols': ['FAKSP', 'SPRAS', 'VTEXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'TVST':  {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['VSTEL', 'SPRAS'],
              'silver_cols': ['VSTEL', 'SPRAS', 'VTEXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'TVROT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['ROUTE', 'SPRAS'],
              'silver_cols': ['ROUTE', 'SPRAS', 'BEZEI'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'TMVFT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['MTVFP', 'SPRAS'],
              'silver_cols': ['MTVFP', 'SPRAS', 'BEZEI'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'T178T': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['KONDM', 'SPRAS'],
              'silver_cols': ['KONDM', 'SPRAS', 'VTEXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # Source columns: MANDT, SPRAS, PRCTR, DATBI, KOKRS, SYSTEM (key field is DATBI not DATAB)
    'CEPCT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['KOKRS', 'PRCTR', 'DATBI', 'SPRAS'],
              'silver_cols': ['KOKRS', 'PRCTR', 'DATBI', 'SPRAS', 'MCTXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # T459W — purple (not yet in source extract); uncomment when available
    # 'T459W': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
    #           'primary_keys': ['BEDAE', 'SPRAS'],
    #           'silver_cols': ['BEDAE', 'SPRAS', 'BDTXT'],
    #           'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'T006A': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['MSEHI', 'SPRAS'],
              'silver_cols': ['MSEHI', 'SPRAS', 'MSEHT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # ── Schedule Line (VBEP) desc ─────────────────────────────────────────────
    'TVEPT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['ETTYP', 'SPRAS'],
              'silver_cols': ['ETTYP', 'SPRAS', 'VTEXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'TVLST': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['LIFSP', 'SPRAS'],
              'silver_cols': ['LIFSP', 'SPRAS', 'VTEXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # ── Delivery Header (LIKP) desc ───────────────────────────────────────────
    'TVSTT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['VSTEL', 'SPRAS'],
              'silver_cols': ['VSTEL', 'SPRAS', 'VTEXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # TVLKT — purple (not yet in source extract); uncomment when available
    # 'TVLKT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
    #           'primary_keys': ['LFART', 'SPRAS'],
    #           'silver_cols': ['LFART', 'SPRAS', 'VTEXT'],
    #           'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'TINCT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['INCO1', 'SPRAS'],
              'silver_cols': ['INCO1', 'SPRAS', 'BEZEI'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'TPRIT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['LPRIO', 'SPRAS'],
              'silver_cols': ['LPRIO', 'SPRAS', 'BEZEI'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # TTGRT — purple (not yet in source extract); uncomment when available
    # 'TTGRT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
    #           'primary_keys': ['TRAGR', 'SPRAS'],
    #           'silver_cols': ['TRAGR', 'SPRAS', 'VTEXT'],
    #           'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # T300T — purple (not yet in source extract); uncomment when available
    # 'T300T': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
    #           'primary_keys': ['LGNUM', 'SPRAS'],
    #           'silver_cols': ['LGNUM', 'SPRAS', 'LNUMT'],
    #           'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # TTSGT — purple (not yet in source extract); uncomment when available
    # 'TTSGT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
    #           'primary_keys': ['TRSPG', 'SPRAS'],
    #           'silver_cols': ['TRSPG', 'SPRAS', 'BEZEI'],
    #           'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # T30CT — purple (not yet in source extract); uncomment when available
    # 'T30CT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
    #           'primary_keys': ['LGNUM', 'LGBZO', 'SPRAS'],
    #           'silver_cols': ['LGNUM', 'LGBZO', 'SPRAS', 'LBZOT'],
    #           'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'T173T': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['VSART', 'SPRAS'],
              'silver_cols': ['VSART', 'SPRAS', 'BEZEI'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # ── Delivery Item (LIPS) desc ─────────────────────────────────────────────
    # TGSBT — purple (not yet in source extract); uncomment when available
    # 'TGSBT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
    #           'primary_keys': ['GSBER', 'SPRAS'],
    #           'silver_cols': ['GSBER', 'SPRAS', 'GTEXT'],
    #           'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'T148T': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['SOBKZ', 'SPRAS'],
              'silver_cols': ['SOBKZ', 'SPRAS', 'SOTXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'TVAPT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['PSTYV', 'SPRAS'],
              'silver_cols': ['PSTYV', 'SPRAS', 'VTEXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'TLGRT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['LADGR', 'SPRAS'],
              'silver_cols': ['LADGR', 'SPRAS', 'VTEXT'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # TVEGRT — purple (not yet in source extract); uncomment when available
    # 'TVEGRT':{'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
    #           'primary_keys': ['MAGRV', 'SPRAS'],
    #           'silver_cols': ['MAGRV', 'SPRAS', 'BEZEI'],
    #           'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    # TMFGT — purple (not yet in source extract); uncomment when available
    # 'TMFGT': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
    #           'primary_keys': ['MFRGR', 'SPRAS'],
    #           'silver_cols': ['MFRGR', 'SPRAS', 'BEZEI'],
    #           'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},

    'T023T': {'source_lh_key': 'SOURCE_MD_LH_ABFSS', 'source_schema': '',
              'primary_keys': ['MATKL', 'SPRAS'],
              'silver_cols': ['MATKL', 'SPRAS', 'WGBEZ'],
              'rename_map': {}, 'desc_joins': [], 'sk_joins': [], 'id_cols': [], 'lzero_cols': [], 'gold_name': '', 'sk_col': ''},
}

print(f'SD desc config loaded: {len(SD_DESC_CONFIGS)} tables')
